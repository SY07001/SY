# %% [markdown]
# <a href="https://colab.research.google.com/github/SY07001/SY/blob/master/Assessments8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("jiebaR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’

# %%
install.packages("tmcn")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("lubridate")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("stringr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("wordcloud")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("Rwordseg",repos = "http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “dependency ‘HMM’ is not available”
# Warning message in install.packages("Rwordseg", repos = "http://R-Forge.R-project.org"):
# “installation of package ‘Rwordseg’ had non-zero exit status”

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library(lubridate)
# Out:
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
library(stringr)

# %%
library(jiebaR)
# Out:
# Loading required package: jiebaRD

# %%
library(wordcloud)
# Out:
# Loading required package: RColorBrewer

# %%
content <- "記得那天太陽壓著平原風慢慢吹沒有人掉眼淚一切好美好到我可以不用說話金色的側臉踩著全白球鞋風繼續吹世界繼續作業那麼確定我知道那就是你那一天你走進了我的生命謝謝你成為了我的幾分之幾閉上眼睛也能看見你晴朗的南方就算犯錯你拿歲月等我就算停留還有你和夜空更多更詳盡歌詞我算什麼讓你無條件的為我那一天你走進了我的生命謝謝你成為了我的幾分之幾如果我又更完整一點也是因為你某一天你離開了我的生命謝謝你曾經是我的幾分之幾感覺貼著我胸口呼吸在那一個回不去的天明我的幾分之幾你終於還是離開我的生命留下每天都在變老的我請記得我曾經愛過記得那天太陽壓著平原風慢慢吹沒有人掉眼淚一切好美好到我可以不用說話金色的側臉踩著全白球鞋風繼續吹世界繼續作業那麼確定我知道那就是你那一天你走進了我的生命謝謝你成為了我的幾分之幾閉上眼睛也能看見你晴朗的南方就算犯錯你拿歲月等我就算停留還有你和夜空更多更詳盡歌詞我算什麼讓你無條件的為我那一天你走進了我的生命謝謝你成為了我的幾分之幾如果我又更完整一點也是因為你某一天你離開了我的生命謝謝你曾經是我的幾分之幾感覺貼著我胸口呼吸在那一個回不去的天明我的幾分之幾你終於還是"

# %%
content
# Out:
# [1] "記得那天太陽壓著平原風慢慢吹沒有人掉眼淚一切好美好到我可以不用說話金色的側臉踩著全白球鞋風繼續吹世界繼續作業那麼確定我知道那就是你那一天你走進了我的生命謝謝你成為了我的幾分之幾閉上眼睛也能看見你晴朗的南方就算犯錯你拿歲月等我就算停留還有你和夜空更多更詳盡歌詞我算什麼讓你無條件的為我那一天你走進了我的生命謝謝你成為了我的幾分之幾如果我又更完整一點也是因為你某一天你離開了我的生命謝謝你曾經是我的幾分之幾感覺貼著我胸口呼吸在那一個回不去的天明我的幾分之幾你終於還是離開我的生命留下每天都在變老的我請記得我曾經愛過記得那天太陽壓著平原風慢慢吹沒有人掉眼淚一切好美好到我可以不用說話金色的側臉踩著全白球鞋風繼續吹世界繼續作業那麼確定我知道那就是你那一天你走進了我的生命謝謝你成為了我的幾分之幾閉上眼睛也能看見你晴朗的南方就算犯錯你拿歲月等我就算停留還有你和夜空更多更詳盡歌詞我算什麼讓你無條件的為我那一天你走進了我的生命謝謝你成為了我的幾分之幾如果我又更完整一點也是因為你某一天你離開了我的生命謝謝你曾經是我的幾分之幾感覺貼著我胸口呼吸在那一個回不去的天明我的幾分之幾你終於還是"

# %%
cutter

# %%
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "記得"     "那天"     "太陽"     "壓著"     "平原"     "風"
#   [7] "慢慢"     "吹"       "沒有"     "人掉"     "眼淚"     "一切"
#  [13] "好"       "美好"     "到"       "我"       "可以"     "不用"
#  [19] "說話"     "金色"     "的"       "側臉"     "踩"       "著"
#  [25] "全白"     "球鞋"     "風"       "繼續"     "吹"       "世界"
#  [31] "繼續"     "作業"     "那麼"     "確定"     "我"       "知道"
#  [37] "那"       "就是"     "你"       "那"       "一天"     "你"
#  [43] "走進"     "了"       "我"       "的"       "生命"     "謝謝"
#  [49] "你"       "成為"     "了"       "我"       "的"       "幾分"
#  [55] "之"       "幾"       "閉上眼睛" "也"       "能"       "看見"
#  [61] "你"       "晴朗"     "的"       "南方"     "就算"     "犯錯"
#  [67] "你"       "拿"       "歲月"     "等"       "我"       "就算"
#  [73] "停留"     "還有"     "你"       "和"       "夜空"     "更"
#  [79] "多"       "更"       "詳盡"     "歌詞"     "我算"     "什麼"
#  [85] "讓"       "你"       "無條件"   "的"       "為"       "我"
#  [91] "那"       "一天"     "你"       "走進"     "了"       "我"
# ...

# %%
new_words <-c("幾分之幾","全白球鞋","金色的側臉")
for(i in 1:length(new_words)) {
  new_user_word(cutter,new_words[i])
}

# %%
content <-str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "記得"       "那天"       "太陽"       "壓著"       "平原"
#   [6] "風"         "慢慢"       "吹"         "沒有"       "人掉"
#  [11] "眼淚"       "一切"       "好"         "美好"       "到"
#  [16] "我"         "可以"       "不用"       "說話"       "金色的側臉"
#  [21] "踩"         "著"         "全白球鞋"   "風"         "繼續"
#  [26] "吹"         "世界"       "繼續"       "作業"       "那麼"
#  [31] "確定"       "我"         "知道"       "那"         "就是"
#  [36] "你"         "那"         "一天"       "你"         "走進"
#  [41] "了"         "我"         "的"         "生命"       "謝謝"
#  [46] "你"         "成為"       "了"         "我"         "的"
#  [51] "幾分之幾"   "閉上眼睛"   "也"         "能"         "看見"
#  [56] "你"         "晴朗"       "的"         "南方"       "就算"
#  [61] "犯錯"       "你"         "拿"         "歲月"       "等"
#  [66] "我"         "就算"       "停留"       "還有"       "你"
#  [71] "和"         "夜空"       "更"         "多"         "更"
#  [76] "詳盡"       "歌詞"       "我算"       "什麼"       "讓"
#  [81] "你"         "無條件"     "的"         "為"         "我"
# ...

# %%
new_words <-c("幾分之幾","全白球鞋","金色的側臉")
writeLines(new_words, "new_words.txt")

# %%
stop_words <- c("也","在","之","更","個","未","而","的","與","著","了","那","你","我")
writeLines(stop_words,"stop_words.txt")

# %%
cutter <- worker(user = "new_words.txt", stop_word = "stop_words.txt",
bylines = FALSE)
seg_words <- cutter[content]
seg_words
# Out:
#   [1] "記得"       "那天"       "太陽"       "壓著"       "平原"
#   [6] "風"         "慢慢"       "吹"         "沒有"       "人掉"
#  [11] "眼淚"       "一切"       "好"         "美好"       "到"
#  [16] "可以"       "不用"       "說話"       "金色的側臉" "踩"
#  [21] "全白球鞋"   "風"         "繼續"       "吹"         "世界"
#  [26] "繼續"       "作業"       "那麼"       "確定"       "知道"
#  [31] "就是"       "一天"       "走進"       "生命"       "謝謝"
#  [36] "成為"       "幾分之幾"   "閉上眼睛"   "能"         "看見"
#  [41] "晴朗"       "南方"       "就算"       "犯錯"       "拿"
#  [46] "歲月"       "等"         "就算"       "停留"       "還有"
#  [51] "和"         "夜空"       "多"         "詳盡"       "歌詞"
#  [56] "我算"       "什麼"       "讓"         "無條件"     "為"
#  [61] "一天"       "走進"       "生命"       "謝謝"       "成為"
#  [66] "幾分之幾"   "如果"       "又"         "完整"       "一點"
#  [71] "是"         "因為"       "某"         "一天"       "離開"
#  [76] "生命"       "謝謝"       "曾經"       "是"         "幾分之幾"
#  [81] "感覺"       "貼著"       "胸口"       "呼吸"       "一個"
# ...

# %%
txt_freq <-freq(seg_words)

# %%
txt_freq <-arrange(txt_freq,desc(freq))

# %%
head(txt_freq)
# Out:
#   char     freq
# 1 幾分之幾 8
# 2 生命     7
# 3 謝謝     6
# 4 一天     6
# 5 成為     4
# 6 繼續     4

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(showtext)

# %%
showtext.auto(enable = TRUE)

# %%
par(family=("Microsoft YaHei"))

# %%
wordcloud(txt_freq$char, txt_freq$freq, min.freq =2 ,random.order = F,
ordered.colors=F ,colors = rainbow(nrow(txt_freq)) )
# Out:
# plot without title
